# %% [markdown]
# # Projet Maison 2

# %%
# import des modules usuels
import numpy as np
import pandas as pd

# options d'affichage
pd.set_option("display.min_rows", 16)

# %%
# chargement et traitement des données
GEO = pd.read_csv("correspondance-code-insee-code-postal.csv",
                   sep=';',
                   usecols=range(11),
                   index_col="Code INSEE")
# A COMPLETER avec les colonnes
# - lat, lon : latitude et longitude des communes
GEO[["lat","lon"]] = GEO["geo_point_2d"].str.split(", ", expand=True).astype(float)

# - cp_ville : Code Postal + " " + "Commune"
cp_ville = GEO["Code Postal"] + " " + GEO["Commune"]
GEO["cp_ville"] = cp_ville
GEO
# Out:
#            Code Postal                     Commune        Département  \
# Code INSEE
# 31080            31350          BOULOGNE-SUR-GESSE      HAUTE-GARONNE
# 11143            11510                     FEUILLA               AUDE
# 43028            43200                  BESSAMOREL        HAUTE-LOIRE
# 78506            78660          PRUNAY-EN-YVELINES           YVELINES
# 84081            84310        MORIERES-LES-AVIGNON           VAUCLUSE
# 80462            80150              LAMOTTE-BULEUX              SOMME
# 40200            40410                     MOUSTEY             LANDES
# 17394            17700      SAINT-SATURNIN-DU-BOIS  CHARENTE-MARITIME
# ...                ...                         ...                ...
# 15024            15700                     BRAGEAC             CANTAL
# 76008            76370                     ANCOURT     SEINE-MARITIME
# 02137            02810                   BUSSIARES              AISNE
# 74066            74270                   CHAVANNAZ       HAUTE-SAVOIE
# 67315            67630  NEEWILLER-PRES-LAUTERBOURG           BAS-RHIN
# 07122            07200     LACHAPELLE-SOUS-AUBENAS            ARDECHE
# 01026            01380              BAGE-LE-CHATEL                AIN
# 50224            50160                GUILBERVILLE             MANCHE
#
#                                 Région            Statut  Altitude Moyenne  \
# Code INSEE
# 31080                    MIDI-PYRENEES  Chef-lieu canton             301.0
# 11143             LANGUEDOC-ROUSSILLON    Commune simple             314.0
# 43028                         AUVERGNE    Commune simple             888.0
# 78506                    ILE-DE-FRANCE    Commune simple             155.0
# 84081       PROVENCE-ALPES-COTE D'AZUR    Commune simple              49.0
# 80462                         PICARDIE    Commune simple              59.0
# 40200                        AQUITAINE    Commune simple              49.0
# 17394                 POITOU-CHARENTES    Commune simple              45.0
# ...                                ...               ...               ...
# 15024                         AUVERGNE    Commune simple             555.0
# 76008                  HAUTE-NORMANDIE    Commune simple              80.0
# 02137                         PICARDIE    Commune simple             141.0
# 74066                      RHONE-ALPES    Commune simple             564.0
# 67315                           ALSACE    Commune simple             157.0
# 07122                      RHONE-ALPES    Commune simple             257.0
# 01026                      RHONE-ALPES  Chef-lieu canton             202.0
# 50224                  BASSE-NORMANDIE    Commune simple             165.0
#
#             Superficie  Population                    geo_point_2d  \
# Code INSEE
# 31080           2470.0         1.6   43.2904403081, 0.650641474176
# 11143           2426.0         0.1    42.9291375888, 2.90138923544
# 43028            743.0         0.4    45.1306448726, 4.07952494849
# 78506           2717.0         0.8    48.5267627187, 1.80513972814
# 84081           1042.0         7.6    43.9337788848, 4.90875878315
# 80462            613.0         0.4    50.1865666179, 1.83564836965
# 40200           6736.0         0.7  44.3882918763, -0.750880080586
# 17394           2528.0         0.9  46.1401428747, -0.665133364912
# ...                ...         ...                             ...
# 15024           1222.0         0.1    45.2038604898, 2.26559675808
# 76008           1252.0         0.7    49.9085547953, 1.17898885458
# 02137            769.0         0.1    49.0765910572, 3.25026191909
# 74066            321.0         0.2    46.0500384099, 6.01652644319
# 67315            725.0         0.7    48.9516989257, 8.11931601006
# 07122           1018.0         1.5    44.5622616562, 4.35906947518
# 01026             86.0         0.8    46.3077069231, 4.92862084189
# 50224           2224.0         1.0  48.9866701737, -0.949588175705
#
#                                                     geo_shape        lat  \
# Code INSEE
# 31080       {"type": "Polygon", "coordinates": [[[0.671852...  43.290440
# 11143       {"type": "Polygon", "coordinates": [[[2.906996...  42.929138
# 43028       {"type": "Polygon", "coordinates": [[[4.091674...  45.130645
# 78506       {"type": "Polygon", "coordinates": [[[1.829610...  48.526763
# 84081       {"type": "Polygon", "coordinates": [[[4.927176...  43.933779
# 80462       {"type": "Polygon", "coordinates": [[[1.849459...  50.186567
# 40200       {"type": "Polygon", "coordinates": [[[-0.71016...  44.388292
# 17394       {"type": "Polygon", "coordinates": [[[-0.66124...  46.140143
# ...                                                       ...        ...
# 15024       {"type": "Polygon", "coordinates": [[[2.302124...  45.203860
# 76008       {"type": "Polygon", "coordinates": [[[1.205457...  49.908555
# 02137       {"type": "Polygon", "coordinates": [[[3.258096...  49.076591
# 74066       {"type": "Polygon", "coordinates": [[[6.026228...  46.050038
# 67315       {"type": "Polygon", "coordinates": [[[8.106826...  48.951699
# 07122       {"type": "Polygon", "coordinates": [[[4.356584...  44.562262
# 01026       {"type": "Polygon", "coordinates": [[[4.926593...  46.307707
# 50224       {"type": "Polygon", "coordinates": [[[-0.99753...  48.986670
#
#                  lon                          cp_ville
# Code INSEE
# 31080       0.650641          31350 BOULOGNE-SUR-GESSE
# 11143       2.901389                     11510 FEUILLA
# 43028       4.079525                  43200 BESSAMOREL
# 78506       1.805140          78660 PRUNAY-EN-YVELINES
# 84081       4.908759        84310 MORIERES-LES-AVIGNON
# 80462       1.835648              80150 LAMOTTE-BULEUX
# 40200      -0.750880                     40410 MOUSTEY
# 17394      -0.665133      17700 SAINT-SATURNIN-DU-BOIS
# ...              ...                               ...
# 15024       2.265597                     15700 BRAGEAC
# 76008       1.178989                     76370 ANCOURT
# 02137       3.250262                   02810 BUSSIARES
# 74066       6.016526                   74270 CHAVANNAZ
# 67315       8.119316  67630 NEEWILLER-PRES-LAUTERBOURG
# 07122       4.359069     07200 LACHAPELLE-SOUS-AUBENAS
# 01026       4.928621              01380 BAGE-LE-CHATEL
# 50224      -0.949588                50160 GUILBERVILLE
#
# [36742 rows x 13 columns]

# %% [markdown]
# **Partie A**
#
# - Compléter le chargement des données en ajoutant au dataframe `GEO`
#     - les colonnes "lat" et "lon" avec la latitude et la longitude des communes
#     - une colonne "cp_ville" avec le Code Postal + un espace + et le nom de la Commune
# - Ecrire une fonction `search_city(lat, lon)` qui retourne le "cp_ville" de la commune la plus proche d'un point à partir de sa latitude et sa longitude.
# - Ecrire une fonction `dms2dec(deg, min, sec)` qui convertit les degrés, minutes, secondes en valeur numérique pour pouvoir utiliser la fonction précédente avec un GPS.

# %%
# fonction recherche de ville
def search_city(lat, long):
    GEO["norm"] = GEO.apply(lambda x: np.sqrt(np.square(lat-x.lat)+np.square(long-x.lon)), axis=1) 
    value = GEO["norm"].idxmin()
    return GEO["cp_ville"][value]

# %%
# conversion degrés, minutes, secondes => décimal
def dms2dec(deg, mn, sec):
    return deg + (mn/60) + (sec/3600)

# %%
# %time
# on applique la fonction à une coordonnée tirée au hasard
np.random.seed(0)
a, b = 41.5, 51.1  # latitude min et max de la France métropolitaine
lat = np.random.uniform(a, b)
a, b = -5.1, 9.5  # longitude min et max de la France métropolitaine
lon = np.random.uniform(a, b)
search_city(lat, lon)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.62 µs
# '71330 BOSJEAN'

# %%
# à partir de coordonnées GPS précises
search_city(dms2dec(48, 42, 52), dms2dec(2, 14, 45))
# Out:
# '91120 PALAISEAU'

# %% [markdown]
# **Partie B**
#
# La colonne "geo_shape" comporte des chaines de catactères au format JSON. Elles représentent les formes géométriques des communes qui sont soit des polygones soit composées de plusieurs polygones.
#
# - Utiliser la librairie Python **json** pour parser les valeurs de la colonne "geo_shape" et mettre le résultat (`Series`) dans la variable `GEO_SHAPE`.
# - Ecrire une fonction `get_types()` qui retourne le décompte (`value_counts()`) des valeurs accédées avec la clé "type".
# - Ecrire une fonction `get_coordinates_len()` qui retourne le décompte (`value_counts()`) des longueurs des listes accédées avec la clé "coordinates".
# - Ecrire une fonction `get_most_complex_city()` qui retourne la commune est constituée du plus grand nombre de polygones ?
# - Ecrire une fonction `get_nb_cities_2_polygons()` qui retourne  le nombre de villes qui sont de type "Polygon" mais dont la longueur des listes accédées avec la clé "coordinates" vaut 2 ?
# - **Facultatif :**
# - Pour ces villes vérifier que le premier polygone contient bien le second (enclave). NB : on pourra installer la librairie **shapely**, utiliser la classe Polygon de **shapely.geometry**  et la méthode `contains()`. Sur Windows **shapely** peut nécessiter d'installer manuellement la dll "geos_c.dll" dans le répertoire "Library/bin" de votre environnement Python.

# %%
# GEO_SHAPE
import json

# La variable GEO_SHAPE doit contenir une Serie
# correspondant aux valeurs de la colonne "geo_shape" parsées avec la librairie json
GEO_SHAPE = pd.Series(dtype=object)

GEO[["types","coord"]] = GEO["geo_shape"].str.split("\",", expand=True)
GEO["types"] = GEO["types"].str[10:]
GEO["coord"] = GEO["coord"].str[15:]
GEO_SHAPE = GEO["coord"]
# Out:
# <bound method Series.unique of Code INSEE
# 31080    Polygon
# 11143    Polygon
# 43028    Polygon
# 78506    Polygon
# 84081    Polygon
# 80462    Polygon
# 40200    Polygon
# 17394    Polygon
#           ...
# 15024    Polygon
# 76008    Polygon
# 02137    Polygon
# 74066    Polygon
# 67315    Polygon
# 07122    Polygon
# 01026    Polygon
# 50224    Polygon
# Name: types, Length: 36742, dtype: object>

# %%
# value_counts des valeurs "type"
def get_types():
    return GEO["types"].value_counts()

# %%
get_types()
# Out:
# Polygon         36670
# MultiPolygon       72
# Name: types, dtype: int64

# %%
# value_counts des longueurs de "coordinates"
def get_coordinates_len():
     return GEO["coord"].value_counts()

# %%
get_coordinates_len()
# Out:
#  [[[0.671852008023359, 43.268343740258835], [0.658909106290094, 43.26408629331833], [0.650936412043327, 43.26784594351563], [0.631954762438815, 43.267341506214635], [0.614599943106533, 43.27783114666891], [0.615325237745429, 43.28054704401019], [0.618933377058037, 43.290418241139854], [0.632703603053863, 43.29290769140922], [0.635725394813344, 43.29913861652718], [0.606810974957096, 43.31088599158548], [0.611653374530417, 43.315673021192005], [0.64425277303335, 43.312392395723855], [0.656250024142831, 43.317414027217886], [0.686254891306201, 43.30042113215234], [0.679800800221225, 43.285046628685656], [0.690880497530084, 43.27968634836884], [0.671852008023359, 43.268343740258835]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
#  [[[2.62594802850271, 49.61094687607246], [2.615460411813722, 49.61161507860905], [2.606372165922072, 49.60830594049453], [2.59267761837288, 49.61232266336125], [2.574063241083728, 49.62226963881661], [2.57605731391972, 49.625349919093196], [2.589545668962712, 49.63732988385618], [2.594017814224385, 49.638701804258446], [2.612276777302393, 49.633953820676126], [2.619632433735307, 49.615950648628676], [2.62594802850271, 49.61094687607246]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
#  [[[0.276328920076335, 44.637123639461315], [0.255511074083805, 44.63947334371302], [0.251577318190082, 44.65286981935921], [0.25504313588682, 44.662549611981646], [0.249282871644629, 44.6722074456551], [0.24480444314046, 44.67369044980595], [0.241053550727721, 44.67139894090253], [0.229429560690099, 44.676729595987545], [0.228698301231713, 44.68004436749604], [0.23327156894731, 44.68076239369723], [0.237390382992633, 44.689459275281344], [0.250066801479012, 44.686144706454556], [0.274669264769683, 44.695185129369946], [0.283741457603169, 44.69430918906212], [0.290002236207339, 44.689391102866395], [0.286315949777154, 44.66945586379751], [0.30623100351038, 44.66005187858547], [0.304765751931957, 44.65849383002413], [0.28464699619278, 44.651705049698485], [0.276328920076335, 44.637123639461315]]]}                                                                                                                                                                                                                                                                                                                                                                          1
#  [[[-0.355963974102209, 46.18900015167575], [-0.358685145640719, 46.19168673729176], [-0.363926891009336, 46.195470369634634], [-0.35674587057191, 46.21257302786991], [-0.343340625941662, 46.21437409725416], [-0.335079383816921, 46.21111075901707], [-0.333565810865914, 46.204584781838996], [-0.34380709804098, 46.19351351278725], [-0.355963974102209, 46.18900015167575]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
#  [[[3.579488472715784, 49.691833584898504], [3.576665174389014, 49.69204467870898], [3.570983879646104, 49.69681588732337], [3.561773051437874, 49.69818861358864], [3.570026520313125, 49.710370592834344], [3.560101668788911, 49.717631957206564], [3.574188473862472, 49.726884175964216], [3.596230669189804, 49.73313088227671], [3.608541127609111, 49.72151486389913], [3.606783086058071, 49.71467673440648], [3.581957916395277, 49.70193064440296], [3.579488472715784, 49.691833584898504]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
#  [[[-1.30656121840081, 47.334481774373515], [-1.309285115365858, 47.34081784325493], [-1.327999645501623, 47.355601461687435], [-1.287753706791807, 47.37127625209939], [-1.225970494796472, 47.37049401000665], [-1.221046207235399, 47.358349567772144], [-1.207717557334286, 47.355029088829866], [-1.228372674932476, 47.34997836738899], [-1.232282931873627, 47.34792464627962], [-1.256388169616392, 47.341282394437314], [-1.282247384885886, 47.340565502747275], [-1.30656121840081, 47.334481774373515]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
#  [[[6.03911193007333, 49.42764721848981], [6.033342844335423, 49.42990574547105], [6.038909057714635, 49.43518990729468], [6.042151281888327, 49.44780890463761], [6.056329823320289, 49.46540491337328], [6.071874277804115, 49.465029566585976], [6.086263906535826, 49.45575894694219], [6.100813289621212, 49.45288662367146], [6.100086628401426, 49.44975704782958], [6.100565165369328, 49.446479660631134], [6.091306090753023, 49.43886396381712], [6.096610962600145, 49.4332684107537], [6.070095096472659, 49.43267574879413], [6.03911193007333, 49.42764721848981]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
#  [[[6.2038729844357, 48.69865713494127], [6.192449220822994, 48.703095403492235], [6.20080032658689, 48.70710235389272], [6.206522070534288, 48.716337477484885], [6.206835618351568, 48.71302540388414], [6.215279744855677, 48.709881447997255], [6.21467607519912, 48.69941054975381], [6.2038729844357, 48.69865713494127]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ..
#  [[[-3.224858573991365, 48.54642531460741], [-3.210123398433874, 48.559793972198605], [-3.212703255398906, 48.56961175837208], [-3.221514644183678, 48.573048485668735], [-3.231463671124631, 48.59902845350878], [-3.220424400989827, 48.60240415367607], [-3.211157803284682, 48.600443691176054], [-3.190198899037288, 48.60749263452191], [-3.189953851779536, 48.60427521627605], [-3.175829261892813, 48.607590704458396], [-3.147601031620149, 48.6022965913783], [-3.14864791456076, 48.58934015338621], [-3.164922429850971, 48.58260473978596], [-3.162270475772826, 48.57314208690241], [-3.170547716091807, 48.56746992052279], [-3.179913740799488, 48.56930171665916], [-3.195418231764677, 48.55236016698247], [-3.218813790900433, 48.547707736118724], [-3.224858573991365, 48.54642531460741]]]}                                                                                                                                                                                                                                                                                                                                                                                               1
#  [[[-0.343361794222077, 44.97811357226285], [-0.355556434024686, 44.98265765536907], [-0.364054732827704, 44.993494511857406], [-0.361771076826365, 44.99628515861857], [-0.357532487489557, 45.00079297183574], [-0.348881464591691, 44.999503733385325], [-0.337895554161299, 45.005700642703104], [-0.331634358373395, 45.00764563939917], [-0.317733331519893, 45.00801603135353], [-0.313131123244665, 45.00216041664743], [-0.30841878484687, 45.001732940517655], [-0.311208224609954, 44.9962789861042], [-0.315916926945244, 44.99557997872889], [-0.322694850244677, 44.98651919419642], [-0.343361794222077, 44.97811357226285]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
#  [[[-0.541812356749666, 48.11466281437664], [-0.549310694208498, 48.12676846652381], [-0.557906593001903, 48.12395116588099], [-0.5651650886109, 48.11528270397668], [-0.57426396334176, 48.11815073698568], [-0.579837605681255, 48.12754767166076], [-0.568576077243665, 48.13451871571183], [-0.564419387055553, 48.16026156333434], [-0.549019827431038, 48.16149157469441], [-0.546527535428702, 48.15505429583093], [-0.550843842281261, 48.141971858473084], [-0.540913598113516, 48.141396801353636], [-0.526606565322001, 48.13271024895768], [-0.527526222879417, 48.1263325608974], [-0.520424348593981, 48.11787983135638], [-0.541812356749666, 48.11466281437664]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
#  [[[0.144861161002352, 44.309710121028566], [0.137278431615358, 44.31802481429019], [0.137632545046778, 44.32542006015415], [0.155882709022713, 44.345799860543316], [0.174301663664961, 44.34921998404999], [0.188908694665385, 44.35866457897337], [0.204744964454861, 44.35805927418653], [0.199284647616875, 44.3491563656753], [0.202191922393623, 44.3434117070655], [0.219606307954719, 44.340736851126955], [0.223382449328751, 44.34256160888225], [0.196779019769719, 44.318116927247495], [0.187705269595647, 44.31893902288121], [0.144861161002352, 44.309710121028566]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
#  [[[0.76380691808185, 47.33885229391325], [0.744931912071209, 47.3359116105106], [0.723126568855793, 47.349940711423365], [0.713862552603922, 47.34748023288234], [0.70463034849439, 47.350180075817455], [0.717267991287781, 47.373331190680176], [0.737330560765876, 47.37668647093443], [0.739094219326689, 47.370389712739716], [0.750946230849766, 47.37479838943445], [0.762376867087661, 47.369651627134374], [0.758050252425505, 47.35962584772555], [0.76380691808185, 47.33885229391325]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
#  [[[5.006007553349622, 43.469671210411526], [5.001471385571892, 43.46892709186057], [4.988078264424628, 43.47826324994013], [4.975898881157651, 43.47413007556088], [4.962223327961786, 43.476070409209434], [4.956122389956373, 43.485630292528796], [4.928669800612378, 43.51065522028741], [4.8818120904084, 43.541447351101766], [4.889743433534335, 43.55426037464736], [4.883109644915932, 43.57837862531725], [4.885631238104194, 43.58881098851295], [4.918347455963322, 43.61481596772448], [4.922604443267195, 43.61653180890064], [4.941029580190569, 43.62103749748528], [4.945895912681021, 43.62095946853817], [4.95454937222511, 43.61276672572029], [4.978382126979224, 43.61633163795195], [4.980134685325548, 43.606093105949654], [4.970716306198081, 43.59909999358726], [5.004219401259197, 43.5654914658145], [5.004160332947293, 43.55210014033887], [5.009774669596695, 43.55623545703047], [5.014440811193737, 43.555545945830204], [5.015529553140394, 43.52768810591144], [5.002876950689, 43.51318035367135], [4.998849823755379, 43.502994703476105], [5.003366063740991, 43.48216671142805], [5.000633769389205, 43.47539534954488], [5.006007553349622, 43.469671210411526]]]}    1
#  [[[-0.501097065157415, 44.4728883183439], [-0.50936752053305, 44.47981601346064], [-0.544576921035783, 44.48752925838736], [-0.545247888247453, 44.497618257831945], [-0.529973358328998, 44.518527726929], [-0.525771819944352, 44.531719399178485], [-0.500842442087762, 44.52625960736086], [-0.483055636083116, 44.52277672498527], [-0.48156446775965, 44.51595742918298], [-0.473675393803858, 44.51218731234487], [-0.474598492624491, 44.508770126784604], [-0.484032927764519, 44.48901787685002], [-0.497193372788209, 44.4862673195688], [-0.501097065157415, 44.4728883183439]]]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
#  [[[-0.997539314886753, 48.950278285217586], [-1.000053818069497, 48.9566591898584], [-0.982300117516146, 48.963706363758426], [-0.980967067909065, 48.967010018744105], [-0.988045783811596, 48.975850411608256], [-0.983149530941796, 48.98173955672255], [-0.96931083690594, 48.982513743545745], [-0.973954070083658, 49.00547180269108], [-0.954384623002716, 49.0040389312099], [-0.94417529925702, 49.014296639849206], [-0.936472781355312, 49.01055229905685], [-0.90704981861495, 49.01585378003795], [-0.905113052660074, 49.011397388203335], [-0.909472115710981, 48.9985881497695], [-0.915084322659666, 48.989545956201894], [-0.944261839188361, 48.96699031221025], [-0.954799815506083, 48.966021739198865], [-0.990474128909743, 48.95084699943612], [-0.997539314886753, 48.950278285217586]]]}                                                                                                                                                                                                                                                                                                                                                                                              1
# Name: coord, Length: 36742, dtype: int64

# %%
# commune constituée du plus grand nombre de polygones
def get_most_complex_city():
    pass

# %%
# commune constituée du plus grand nombre de polygones
def get_nb_cities_2_polygons():
    pass

# %%
# tests
import unittest

class Session2Test(unittest.TestCase):
    
    def test_partie_A1(self):
        # on applique la fonction cherche_ville() à une coordonnée tirée au hasard
        np.random.seed(0)
        a, b = 41.5, 51.1  # latitude min et max de la France métropolitaine
        lat = np.random.uniform(a, b)
        a, b = -5.1, 9.5  # longitude min et max de la France métropolitaine
        lon = np.random.uniform(a, b)

        cp_ville = search_city(lat, lon)
        self.assertEqual(cp_ville, "71330 BOSJEAN")
        
    def test_partie_A2(self):
        # à partir de coordonnées GPS précises
        cp_ville = search_city(dms2dec(48, 42, 52), dms2dec(2, 14, 45))
        self.assertEqual(cp_ville, "91120 PALAISEAU")
        
    def test_partie_B1(self):
        # check types
        dico = get_types()
        self.assertEqual(dico["Polygon"], 36670)
        self.assertEqual(dico["MultiPolygon"], 72)
        
    def test_partie_B2(self):
        # check coordinates len
        dico = get_coordinates_len()
        self.assertEqual(dico[1], 36660)
        self.assertEqual(dico[2], 80)
       
    def test_partie_B3(self):
        # check most complex city
        cp_ville = get_most_complex_city()
        self.assertEqual(cp_ville, "83400 HYERES")
        
    def test_partie_B4(self):
        # check nb cities 2 polygons
        nb = get_nb_cities_2_polygons()
        self.assertEqual(nb, 10)

# %%
# run tests
def run_tests():
    test_suite = unittest.makeSuite(Session2Test)
    runner = unittest.TextTestRunner(verbosity=2)
    runner.run(test_suite)
    
run_tests()
# Out:
# test_partie_A1 (__main__.Session2Test) ... ok
# test_partie_A2 (__main__.Session2Test) ... ok
# test_partie_B1 (__main__.Session2Test) ... ok
# test_partie_B2 (__main__.Session2Test) ... FAIL
# test_partie_B3 (__main__.Session2Test) ... ERROR
# test_partie_B4 (__main__.Session2Test) ... ERROR
#
# ======================================================================
# ERROR: test_partie_B3 (__main__.Session2Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_130/3431394153.py", line 36, in test_partie_B3
#     cp_ville = get_most_complex_city()
# NameError: name 'get_most_complex_city' is not defined
#
# ======================================================================
# ERROR: test_partie_B4 (__main__.Session2Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_130/3431394153.py", line 41, in test_partie_B4
#     nb = get_nb_cities_2_polygons()
# NameError: name 'get_nb_cities_2_polygons' is not defined
#
# ======================================================================
# FAIL: test_partie_B2 (__main__.Session2Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_130/3431394153.py", line 31, in test_partie_B2
#     self.assertEqual(dico[1], 36660)
# AssertionError: 1 != 36660
#
# ----------------------------------------------------------------------
# Ran 6 tests in 1.024s
#
# FAILED (failures=1, errors=2)
